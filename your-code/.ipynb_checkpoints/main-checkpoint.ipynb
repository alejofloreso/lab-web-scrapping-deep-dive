# %% [markdown]
# # Advanced Web Scraping Lab
#
# In this lab you will first learn the following code snippet which is a simple web spider class that allows you to scrape paginated webpages. Read the code, run it, and make sure you understand how it work. In the challenges of this lab, we will guide you in building up this class so that eventually you will have a more robus web spider that you can further work on in the Web Scraping Project.

# %%
import asyncio
import pandas as pd
import requests
from bs4 import BeautifulSoup

class IronhackSpider:
    """
    This is the constructor class to which you can pass a bunch of parameters. 
    These parameters are stored to the class instance variables so that the
    class functions can access them later.
    
    url_pattern: the regex pattern of the web urls to scape
    pages_to_scrape: how many pages to scrape
    sleep_interval: the time interval in seconds to delay between requests. If <0, requests will not be delayed.
    content_parser: a function reference that will extract the intended info from the scraped content.
    """
    def __init__(self, url_pattern, pages_to_scrape=10, sleep_interval=-1, content_parser=None):
        self.url_pattern = url_pattern
        self.pages_to_scrape = pages_to_scrape
        self.sleep_interval = sleep_interval
        self.content_parser = content_parser
    
    """
    Scrape the content of a single url.
    """
    def scrape_url(self, url):
        response = requests.get(url)
        result = self.content_parser(response.content)
        self.output_results(result)
    
    """
    Export the scraped content. Right now it simply print out the results.
    But in the future you can export the results into a text file or database.
    """
    def output_results(self, r):
        print(r)
    
    """
    After the class is instantiated, call this function to start the scraping jobs.
    This function uses a FOR loop to call `scrape_url()` for each url to scrape.
    """
    def kickstart(self):
        for i in range(1, self.pages_to_scrape+1):
            self.scrape_url(self.url_pattern % i)


URL_PATTERN = 'http://quotes.toscrape.com/page/%s/' # regex pattern for the urls to scrape
PAGES_TO_SCRAPE = 1 # how many webpages to scrape

"""
This is a custom parser function you will complete in the challenge.
Right now it simply returns the string passed to it. But in this lab
you will complete this function so that it extracts the quotes.
This function will be passed to the IronhackSpider class.
"""
def quotes_parser(content):
    return content

# Instantiate the IronhackSpider class
my_spider = IronhackSpider(URL_PATTERN, PAGES_TO_SCRAPE, content_parser=quotes_parser)

# Start scraping jobs
my_spider.kickstart()
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n    <link rel="stylesheet" href="/static/bootstrap.min.css">\n    <link rel="stylesheet" href="/static/main.css">\n</head>\n<body>\n    <div class="container">\n        <div class="row header-box">\n            <div class="col-md-8">\n                <h1>\n                    <a href="/" style="text-decoration: none">Quotes to Scrape</a>\n                </h1>\n            </div>\n            <div class="col-md-4">\n                <p>\n                \n                    <a href="/login">Login</a>\n                \n                </p>\n            </div>\n        </div>\n    \n\n<div class="row">\n    <div class="col-md-8">\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cThe world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.\xe2\x80\x9d</span>\n        <span>by <small class="author" itemprop="author">Albert Einstein</small>\n        <a href="/author/Albert-Einstein">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="change,deep-thoughts,thinking,world" /    > \n            \n            <a class="tag" href="/tag/change/page/1/">change</a>\n            \n            <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>\n            \n            <a class="tag" href="/tag/thinking/page/1/">thinking</a>\n            \n            <a class="tag" href="/tag/world/page/1/">world</a>\n            \n        </div>\n    </div>\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cIt is our choices, Harry, that show what we truly are, far more than our abilities.\xe2\x80\x9d</span>\n        <span>by <small class="author" itemprop="author">J.K. Rowling</small>\n        <a href="/author/J-K-Rowling">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="abilities,choices" /    > \n            \n            <a class="tag" href="/tag/abilities/page/1/">abilities</a>\n            \n            <a class="tag" href="/tag/choices/page/1/">choices</a>\n            \n        </div>\n    </div>\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cThere are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.\xe2\x80\x9d</span>\n        <span>by <small class="author" itemprop="author">Albert Einstein</small>\n        <a href="/author/Albert-Einstein">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="inspirational,life,live,miracle,miracles" /    > \n            \n            <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>\n            \n            <a class="tag" href="/tag/life/page/1/">life</a>\n            \n            <a class="tag" href="/tag/live/page/1/">live</a>\n            \n            <a class="tag" href="/tag/miracle/page/1/">miracle</a>\n            \n            <a class="tag" href="/tag/miracles/page/1/">miracles</a>\n            \n        </div>\n    </div>\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cThe person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.\xe2\x80\x9d</span>\n        <span>by <small class="author" itemprop="author">Jane Austen</small>\n        <a href="/author/Jane-Austen">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" conten ...

# %% [markdown]
# ## Challenge 1 - Custom Parser Function
#
# In this challenge, complete the custom `quotes_parser()` function so that the returned result contains the quote string instead of the whole html page content.
#
# In the cell below, write your updated `quotes_parser()` function and kickstart the spider. Make sure the results being printed contain a list of quote strings extracted from the html content.

# %%
# your code here
def quotes_parser(content):
    soup = BeautifulSoup(content, "lxml")
    quotes = soup.find_all('span', {'class':'text'})
    authors = soup.find_all('small', {'class':'author'})
    data = [quote.text.replace("'","").strip() for quote in quotes]
    data2 = [au.text.replace("'","").strip() for au in authors]
    df = pd.DataFrame(list(zip(data, data2)), columns = ['Quotes', 'Authors'])
    return df

my_spider = IronhackSpider(URL_PATTERN, PAGES_TO_SCRAPE, content_parser=quotes_parser)
my_spider.kickstart()
# Out:
#                                               Quotes            Authors
# 0  “The world as we have created it is a process ...    Albert Einstein
# 1  “It is our choices, Harry, that show what we t...       J.K. Rowling
# 2  “There are only two ways to live your life. On...    Albert Einstein
# 3  “The person, be it gentleman or lady, who has ...        Jane Austen
# 4  “Imperfection is beauty, madness is genius and...     Marilyn Monroe
# 5  “Try not to become a man of success. Rather be...    Albert Einstein
# 6  “It is better to be hated for what you are tha...         André Gide
# 7  “I have not failed. Ive just found 10,000 ways...   Thomas A. Edison
# 8  “A woman is like a tea bag; you never know how...  Eleanor Roosevelt
# 9  “A day without sunshine is like, you know, nig...       Steve Martin

# %%
URL_PATTERN = 'http://books.toscrape.com/catalogue/page-%s.html' # regex pattern for the urls to scrape
PAGES_TO_SCRAPE = 1 # how many webpages to scrape

def quotes_parser(content):
    soup = BeautifulSoup(content, "lxml")
    titles = [title.a['title'] for title in soup.find_all('h3')]
    Price = soup.find_all('p', {'class':'price_color'})
    Price_clean = [p.text.strip() for p in Price]
    df = pd.DataFrame(list(zip(titles, Price_clean)), columns = ['Book', 'Price'])
    return df

# Instantiate the IronhackSpider class
my_spider = IronhackSpider(URL_PATTERN, PAGES_TO_SCRAPE, content_parser=quotes_parser)

# Start scraping jobs
my_spider.kickstart()
# Out:
#                                                  Book   Price
# 0                                A Light in the Attic  £51.77
# 1                                  Tipping the Velvet  £53.74
# 2                                          Soumission  £50.10
# 3                                       Sharp Objects  £47.82
# 4               Sapiens: A Brief History of Humankind  £54.23
# 5                                     The Requiem Red  £22.65
# 6   The Dirty Little Secrets of Getting Your Dream...  £33.34
# 7   The Coming Woman: A Novel Based on the Life of...  £17.93
# 8   The Boys in the Boat: Nine Americans and Their...  £22.60
# 9                                     The Black Maria  £52.15
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  £13.99
# 11                              Shakespeare's Sonnets  £20.66
# 12                                        Set Me Free  £17.46
# 13  Scott Pilgrim's Precious Little Life (Scott Pi...  £52.29
# 14                          Rip it Up and Start Again  £35.02
# 15  Our Band Could Be Your Life: Scenes from the A...  £57.25
# 16                                               Olio  £23.88
# 17  Mesaerion: The Best Science Fiction Stories 18...  £37.59
# 18                       Libertarianism for Beginners  £51.33
# 19                            It's Only the Himalayas  £45.17

# %% [markdown]
# ## Challenge 2 - Error Handling
#
# In `IronhackSpider.scrape_url()`, catch any error that might occur when you make requests to scrape the webpage. This includes checking the response status code and catching http request errors such as timeout, SSL, and too many redirects.
#
# In the cell below, place your entire code including the updated `IronhackSpdier` class and the code to kickstart the spider.

# %%
def quotes_parser(content):
    soup = BeautifulSoup(content, "lxml")
    quotes = soup.find_all('span', {'class':'text'})
    authors = soup.find_all('small', {'class':'author'})
    data = [quote.text.replace("'","").strip() for quote in quotes]
    data2 = [au.text.replace("'","").strip() for au in authors]
    df = pd.DataFrame(list(zip(data, data2)), columns = ['Quotes', 'Authors'])
    return df

# your code here

def scrape_url(self, url):
    try:
        response = requests.get(url, timeout=10)
        if response.status_code < 300:
            result = self.content_parser(response.content)
            self.output_results(result)
        elif r.status_code >= 400 and r.status_code < 500:
            print('request failed because the resource either does not exist or is forbidden'.format(response.status_code, url))
        else:
            print('request failed because the response server encountered an error'.format(response.status_code, url))
    except requests.exceptions.Timeout:
        print ('Timeout error')
    except requests.exceptions.TooManyRedirects:
        print('redirect error... do something')
    except requests.exceptions.SSLError:
        print('ssl error... do something')
    except requests.exceptions.RequestException as e:
        print('other unknown errors... do something')

my_spider = IronhackSpider(URL_PATTERN, PAGES_TO_SCRAPE, content_parser=quotes_parser)
my_spider.kickstart()
# Out:
#                                               Quotes            Authors
# 0  “The world as we have created it is a process ...    Albert Einstein
# 1  “It is our choices, Harry, that show what we t...       J.K. Rowling
# 2  “There are only two ways to live your life. On...    Albert Einstein
# 3  “The person, be it gentleman or lady, who has ...        Jane Austen
# 4  “Imperfection is beauty, madness is genius and...     Marilyn Monroe
# 5  “Try not to become a man of success. Rather be...    Albert Einstein
# 6  “It is better to be hated for what you are tha...         André Gide
# 7  “I have not failed. Ive just found 10,000 ways...   Thomas A. Edison
# 8  “A woman is like a tea bag; you never know how...  Eleanor Roosevelt
# 9  “A day without sunshine is like, you know, nig...       Steve Martin

# %% [markdown]
# # Challenge 3 - Sleep Interval
#
# In `IronhackSpider.kickstart()`, implement `sleep_interval`. You will check if `self.sleep_interval` is larger than 0. If so, tell the FOR loop to sleep the given amount of time before making the next request.
#
# In the cell below, place your entire code including the updated `IronhackSpdier` class and the code to kickstart the spider.

# %%
# your code here
def kickstart(self):
    interval = 0
    if self.sleep_interval>0:
        interval = self.sleep.interval
    for i in range(1, self.pages_to_scrape+1):
        self.scrape_url(self.url_pattern % i)
        time.sleep(3)

# %%
import time
import asyncio
import pandas as pd
import requests
from bs4 import BeautifulSoup

class IronhackSpider:
    """
    This is the constructor class to which you can pass a bunch of parameters. 
    These parameters are stored to the class instance variables so that the
    class functions can access them later.
    
    url_pattern: the regex pattern of the web urls to scape
    pages_to_scrape: how many pages to scrape
    sleep_interval: the time interval in seconds to delay between requests. If <0, requests will not be delayed.
    content_parser: a function reference that will extract the intended info from the scraped content.
    """
    def __init__(self, url_pattern, pages_to_scrape=10, sleep_interval=-1, content_parser=None):
        self.url_pattern = url_pattern
        self.pages_to_scrape = pages_to_scrape
        self.sleep_interval = sleep_interval
        self.content_parser = content_parser
    
    """
    Scrape the content of a single url.
    """
    def scrape_url(self, url):
        try:
            response = requests.get(url, timeout=10)
            if response.status_code < 300:
                result = self.content_parser(response.content)
                self.output_results(result)
            elif r.status_code >= 400 and r.status_code < 500:
                print('request failed because the resource either does not exist or is forbidden'.format(response.status_code, url))
            else:
                print('request failed because the response server encountered an error'.format(response.status_code, url))
        except requests.exceptions.Timeout:
            print ('Timeout error')
        except requests.exceptions.TooManyRedirects:
            print('redirect error... do something')
        except requests.exceptions.SSLError:
            print('ssl error... do something')
        except requests.exceptions.RequestException as e:
            print('other unknown errors... do something')
    
    """
    Export the scraped content. Right now it simply print out the results.
    But in the future you can export the results into a text file or database.
    """
    def output_results(self, r):
        print(r)
    
    """
    After the class is instantiated, call this function to start the scraping jobs.
    This function uses a FOR loop to call `scrape_url()` for each url to scrape.
    """
    def kickstart(self):
        interval = 0
        if self.sleep_interval>0:
            interval = self.sleep.interval
        for i in range(1, self.pages_to_scrape+1):
            self.scrape_url(self.url_pattern % i)
            time.sleep(3)


URL_PATTERN = 'http://quotes.toscrape.com/page/%s/' # regex pattern for the urls to scrape
PAGES_TO_SCRAPE = 1 # how many webpages to scrape

"""
This is a custom parser function you will complete in the challenge.
Right now it simply returns the string passed to it. But in this lab
you will complete this function so that it extracts the quotes.
This function will be passed to the IronhackSpider class.
"""
def quotes_parser(content):
    soup = BeautifulSoup(content, "lxml")
    quotes = soup.find_all('span', {'class':'text'})
    authors = soup.find_all('small', {'class':'author'})
    data = [quote.text.replace("'","").strip() for quote in quotes]
    data2 = [au.text.replace("'","").strip() for au in authors]
    df = pd.DataFrame(list(zip(data, data2)), columns = ['Quotes', 'Authors'])
    return df

# Instantiate the IronhackSpider class
my_spider = IronhackSpider(URL_PATTERN, PAGES_TO_SCRAPE, content_parser=quotes_parser)

# Start scraping jobs
my_spider.kickstart()
# Out:
#                                               Quotes            Authors
# 0  “The world as we have created it is a process ...    Albert Einstein
# 1  “It is our choices, Harry, that show what we t...       J.K. Rowling
# 2  “There are only two ways to live your life. On...    Albert Einstein
# 3  “The person, be it gentleman or lady, who has ...        Jane Austen
# 4  “Imperfection is beauty, madness is genius and...     Marilyn Monroe
# 5  “Try not to become a man of success. Rather be...    Albert Einstein
# 6  “It is better to be hated for what you are tha...         André Gide
# 7  “I have not failed. Ive just found 10,000 ways...   Thomas A. Edison
# 8  “A woman is like a tea bag; you never know how...  Eleanor Roosevelt
# 9  “A day without sunshine is like, you know, nig...       Steve Martin

# %% [markdown]
# # Challenge 4 - Test Batch Scraping
#
# Change the `PAGES_TO_SCRAPE` value from `1` to `10`. Try if your code still works as intended to scrape 10 webpages. If there are errors in your code, fix them.
#
# In the cell below, place your entire code including the updated `IronhackSpdier` class and the code to kickstart the spider.

# %%
# your code here
import time
import asyncio
import pandas as pd
import requests
from bs4 import BeautifulSoup

class IronhackSpider:
    """
    This is the constructor class to which you can pass a bunch of parameters. 
    These parameters are stored to the class instance variables so that the
    class functions can access them later.
    
    url_pattern: the regex pattern of the web urls to scape
    pages_to_scrape: how many pages to scrape
    sleep_interval: the time interval in seconds to delay between requests. If <0, requests will not be delayed.
    content_parser: a function reference that will extract the intended info from the scraped content.
    """
    def __init__(self, url_pattern, pages_to_scrape=10, sleep_interval=-1, content_parser=None):
        self.url_pattern = url_pattern
        self.pages_to_scrape = pages_to_scrape
        self.sleep_interval = sleep_interval
        self.content_parser = content_parser
    
    """
    Scrape the content of a single url.
    """
    def scrape_url(self, url):
        try:
            response = requests.get(url, timeout=10)
            if response.status_code < 300:
                result = self.content_parser(response.content)
                self.output_results(result)
            elif r.status_code >= 400 and r.status_code < 500:
                print('request failed because the resource either does not exist or is forbidden'.format(response.status_code, url))
            else:
                print('request failed because the response server encountered an error'.format(response.status_code, url))
        except requests.exceptions.Timeout:
            print ('Timeout error')
        except requests.exceptions.TooManyRedirects:
            print('redirect error... do something')
        except requests.exceptions.SSLError:
            print('ssl error... do something')
        except requests.exceptions.RequestException as e:
            print('other unknown errors... do something')
    
    """
    Export the scraped content. Right now it simply print out the results.
    But in the future you can export the results into a text file or database.
    """
    def output_results(self, r):
        print(r)
    
    """
    After the class is instantiated, call this function to start the scraping jobs.
    This function uses a FOR loop to call `scrape_url()` for each url to scrape.
    """
    def kickstart(self):
        interval = 0
        if self.sleep_interval>0:
            interval = self.sleep.interval
        for i in range(1, self.pages_to_scrape+1):
            self.scrape_url(self.url_pattern % i)
            time.sleep(3)


URL_PATTERN = 'http://quotes.toscrape.com/page/%s/' # regex pattern for the urls to scrape
PAGES_TO_SCRAPE = 10 # how many webpages to scrape

"""
This is a custom parser function you will complete in the challenge.
Right now it simply returns the string passed to it. But in this lab
you will complete this function so that it extracts the quotes.
This function will be passed to the IronhackSpider class.
"""
def quotes_parser(content):
    soup = BeautifulSoup(content, "lxml")
    quotes = soup.find_all('span', {'class':'text'})
    authors = soup.find_all('small', {'class':'author'})
    data = [quote.text.replace("'","").strip() for quote in quotes]
    data2 = [au.text.replace("'","").strip() for au in authors]
    df = pd.DataFrame(list(zip(data, data2)), columns = ['Quotes', 'Authors'])
    return df

# Instantiate the IronhackSpider class
my_spider = IronhackSpider(URL_PATTERN, PAGES_TO_SCRAPE, content_parser=quotes_parser)

# Start scraping jobs
my_spider.kickstart()
# Out:
#                                               Quotes            Authors
# 0  “The world as we have created it is a process ...    Albert Einstein
# 1  “It is our choices, Harry, that show what we t...       J.K. Rowling
# 2  “There are only two ways to live your life. On...    Albert Einstein
# 3  “The person, be it gentleman or lady, who has ...        Jane Austen
# 4  “Imperfection is beauty, madness is genius and...     Marilyn Monroe
# 5  “Try not to become a man of success. Rather be...    Albert Einstein
# 6  “It is better to be hated for what you are tha...         André Gide
# 7  “I have not failed. Ive just found 10,000 ways...   Thomas A. Edison
# 8  “A woman is like a tea bag; you never know how...  Eleanor Roosevelt
# 9  “A day without sunshine is like, you know, nig...       Steve Martin
#                                               Quotes              Authors
# 0  “This life is what you make it. No matter what...       Marilyn Monroe
# 1  “It takes a great deal of bravery to stand up ...         J.K. Rowling
# 2  “If you cant explain it to a six year old, you...      Albert Einstein
# 3  “You may not be her first, her last, or her on...           Bob Marley
# 4  “I like nonsense, it wakes up the brain cells....            Dr. Seuss
# 5  “I may not have gone where I intended to go, b...        Douglas Adams
# 6  “The opposite of love is not hate, its indiffe...          Elie Wiesel
# 7  “It is not a lack of love, but a lack of frien...  Friedrich Nietzsche
# 8  “Good friends, good books, and a sleepy consci...           Mark Twain
# 9  “Life is what happens to us while we are makin...       Allen Saunders
#                                               Quotes              Authors
# 0  “I love you without knowing how, or when, or f...         Pablo Neruda
# 1  “For every minute you are angry you lose sixty...  Ralph Waldo Emerson
# 2  “If you judge people, you have no time to love...        Mother Teresa
# 3  “Anyone who thinks sitting in church can make ...     Garrison Keillor
# 4  “Beauty is in the eye of the beholder and it m...           Jim Henson
# 5  “Today you are You, that is truer than true. T...            Dr. Seuss
# 6  “If you want your children to be intelligent, ...      Albert Einstein
# 7  “It is impossible to live without failing at s...         J.K. Rowling
# 8  “Logic will get you from A to Z; imagination w...      Albert Einstein
# 9  “One good thing about music, when it hits you,...           Bob Marley
#                                               Quotes            Authors
# 0  “The more that you read, the more things you w...          Dr. Seuss
# 1  “Of course it is happening inside your head, H...       J.K. Rowling
# 2  “The truth is, everyone is going to hurt you. ...         Bob Marley
# 3  “Not all of us can do great things. But we can...      Mother Teresa
# 4  “To the well-organized mind, death is but the ...       J.K. Rowling
# 5  “All you need is love. But a little chocolate ...  Charles M. Schulz
# 6                  “We read to know were not alone.”  William Nicholson
# 7   “Any fool can know. The point is to understand.”    Albert Einstein
# 8  “I have always imagined that Paradise will be ...  Jorge Luis Borges
# 9  “It is never too late to be what you might hav...       George Eliot
#                                               Quotes                 Authors
# 0  “A reader lives a thousand lives before he die...      George R.R. Martin
# 1  “You can never get a cup of tea large enough o...              C.S. Lewis
# 2  “You believe lies so you eventually learn to t...          Marilyn Monroe
# 3  “If you can make a woman laugh, you can make h...          Marilyn Monroe
# 4  “Life is like riding a bicycle. To keep your b...         Albert Einstein
# 5  “The real lover is the man who can thrill you ...          Marilyn Monroe
# 6  “A wise girl kisses but doesnt love, listens b...          Marilyn Monroe
# 7      “Only in the darkness can you see the stars.”  Martin Luther King Jr.
# 8  “It matters not what someone is born, but what...            J.K. Rowling
# 9  “Love does not begin and end the way we seem t...           James Baldwin
#                                               Quotes               Authors
# 0  “There is nothing I would not do for those who...           Jane Austen
# 1          “Do one thing every day that scares you.”     Eleanor Roosevelt
# 2  “I am good, but not an angel. I do sin, but I ...        Marilyn Monroe
# 3  “If I were not a physicist, I would probably b...       Albert Einstein
# 4  “If you only read the books that everyone else...       Haruki Murakami
# 5  “The difference between genius and stupidity i...  Alexandre Dumas fils
# 6                  “Hes like a drug for you, Bella.”       Stephenie Meyer
# 7           “There is no friend as loyal as a book.”      Ernest Hemingway
# 8  “When one door of happiness closes, another op...          Helen Keller
# 9  “Life isnt about finding yourself. Life is abo...   George Bernard Shaw
#                                               Quotes              Authors
# 0  “Thats the problem with drinking, I thought, a...     Charles Bukowski
# 1  “You don’t forget the face of the person who w...      Suzanne Collins
# 2  “Remember, were madly in love, so its all righ...      Suzanne Collins
# 3  “To love at all is to be vulnerable. Love anyt...           C.S. Lewis
# 4               “Not all those who wander are lost.”       J.R.R. Tolkien
# 5  “Do not pity the dead, Harry. Pity the living,...         J.K. Rowling
# 6  “There is nothing to writing. All you do is si...     Ernest Hemingway
# 7  “Finish each day and be done with it. You have...  Ralph Waldo Emerson
# 8  “I have never let my schooling interfere with ...           Mark Twain
# 9  “I have heard there are troubles of more than ...            Dr. Seuss
#                                               Quotes           Authors
# 0  “If I had a flower for every time I thought of...   Alfred Tennyson
# 1  “Some people never go crazy. What truly horrib...  Charles Bukowski
# 2  “The trouble with having an open mind, of cour...   Terry Pratchett
# 3  “Think left and think right and think low and ...         Dr. Seuss
# 4  “What really knocks me out is a book that, whe...     J.D. Salinger
# 5  “The reason I talk to myself is because I’m th...     George Carlin
# 6  “You may say Im a dreamer, but Im not the only...       John Lennon
# 7  “I am free of all prejudice. I hate everyone e...       W.C. Fields
# 8  “The question isnt who is going to let me; its...          Ayn Rand
# 9  “′Classic′ - a book which people praise and do...        Mark Twain
#                                               Quotes          Authors
# 0  “Anyone who has never made a mistake has never...  Albert Einstein
# 1  “A ladys imagination is very rapid; it jumps f...      Jane Austen
# 2  “Remember, if the time should come when you ha...     J.K. Rowling
# 3  “I declare after all there is no enjoyment lik...      Jane Austen
# 4  “There are few people whom I really love, and ...      Jane Austen
# 5  “Some day you will be old enough to start read...       C.S. Lewis
# 6  “We are not necessarily doubting that God will...       C.S. Lewis
# 7  “The fear of death follows from the fear of li...       Mark Twain
# 8  “A lie can travel half way around the world wh...       Mark Twain
# 9  “I believe in Christianity as I believe that t...       C.S. Lewis
#                                               Quotes             Authors
# 0  “The truth." Dumbledore sighed. "It is a beaut...        J.K. Rowling
# 1  “Im the one thats got to die when its time for...        Jimi Hendrix
# 2         “To die will be an awfully big adventure.”         J.M. Barrie
# 3  “It takes courage to grow up and become who yo...       E.E. Cummings
# 4  “But better to get hurt by the truth than comf...     Khaled Hosseini
# 5  “You never really understand a person until yo...          Harper Lee
# 6  “You have to write the book that wants to be w...    Madeleine LEngle
# 7  “Never tell the truth to people who are not wo...          Mark Twain
# 8         “A persons a person, no matter how small.”           Dr. Seuss
# 9  “... a mind needs books as a sword needs a whe...  George R.R. Martin

# %% [markdown]
# # Challenge 5 - Scrape a Different Website
#
# Update the parameters passed to the `IronhackSpider` constructor so that you coder can crawl [books.toscrape.com](http://books.toscrape.com/). You will need to use a different `URL_PATTERN` (figure out the new url pattern by yourself) and write another parser function to be passed to `IronhackSpider`.
#
# In the cell below, place your entire code including the updated `IronhackSpdier` class and the code to kickstart the spider.

# %%
# your code here
import time
import asyncio
import pandas as pd
import requests
from bs4 import BeautifulSoup

class IronhackSpider:
    """
    This is the constructor class to which you can pass a bunch of parameters. 
    These parameters are stored to the class instance variables so that the
    class functions can access them later.
    
    url_pattern: the regex pattern of the web urls to scape
    pages_to_scrape: how many pages to scrape
    sleep_interval: the time interval in seconds to delay between requests. If <0, requests will not be delayed.
    content_parser: a function reference that will extract the intended info from the scraped content.
    """
    def __init__(self, url_pattern, pages_to_scrape=10, sleep_interval=-1, content_parser=None):
        self.url_pattern = url_pattern
        self.pages_to_scrape = pages_to_scrape
        self.sleep_interval = sleep_interval
        self.content_parser = content_parser
    
    """
    Scrape the content of a single url.
    """
    def scrape_url(self, url):
        try:
            response = requests.get(url, timeout=10)
            if response.status_code < 300:
                result = self.content_parser(response.content)
                self.output_results(result)
            elif r.status_code >= 400 and r.status_code < 500:
                print('request failed because the resource either does not exist or is forbidden'.format(response.status_code, url))
            else:
                print('request failed because the response server encountered an error'.format(response.status_code, url))
        except requests.exceptions.Timeout:
            print ('Timeout error')
        except requests.exceptions.TooManyRedirects:
            print('redirect error... do something')
        except requests.exceptions.SSLError:
            print('ssl error... do something')
        except requests.exceptions.RequestException as e:
            print('other unknown errors... do something')
    
    """
    Export the scraped content. Right now it simply print out the results.
    But in the future you can export the results into a text file or database.
    """
    def output_results(self, r):
        print(r)
    
    """
    After the class is instantiated, call this function to start the scraping jobs.
    This function uses a FOR loop to call `scrape_url()` for each url to scrape.
    """
    def kickstart(self):
        interval = 0
        if self.sleep_interval>0:
            interval = self.sleep.interval
        for i in range(1, self.pages_to_scrape+1):
            self.scrape_url(self.url_pattern % i)
            time.sleep(3)


URL_PATTERN = 'http://books.toscrape.com/catalogue/page-%s.html' # regex pattern for the urls to scrape
PAGES_TO_SCRAPE = 10 # how many webpages to scrape

"""
This is a custom parser function you will complete in the challenge.
Right now it simply returns the string passed to it. But in this lab
you will complete this function so that it extracts the quotes.
This function will be passed to the IronhackSpider class.
"""
def quotes_parser(content):
    soup = BeautifulSoup(content, "lxml")
    titles = [title.a['title'] for title in soup.find_all('h3')]
    Price = soup.find_all('p', {'class':'price_color'})
    Price_clean = [p.text.strip() for p in Price]
    df = pd.DataFrame(list(zip(titles, Price_clean)), columns = ['Book', 'Price'])
    return df

# Instantiate the IronhackSpider class
my_spider = IronhackSpider(URL_PATTERN, PAGES_TO_SCRAPE, content_parser=quotes_parser)

# Start scraping jobs
my_spider.kickstart()
# Out:
#                                                  Book   Price
# 0                                A Light in the Attic  £51.77
# 1                                  Tipping the Velvet  £53.74
# 2                                          Soumission  £50.10
# 3                                       Sharp Objects  £47.82
# 4               Sapiens: A Brief History of Humankind  £54.23
# 5                                     The Requiem Red  £22.65
# 6   The Dirty Little Secrets of Getting Your Dream...  £33.34
# 7   The Coming Woman: A Novel Based on the Life of...  £17.93
# 8   The Boys in the Boat: Nine Americans and Their...  £22.60
# 9                                     The Black Maria  £52.15
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  £13.99
# 11                              Shakespeare's Sonnets  £20.66
# 12                                        Set Me Free  £17.46
# 13  Scott Pilgrim's Precious Little Life (Scott Pi...  £52.29
# 14                          Rip it Up and Start Again  £35.02
# 15  Our Band Could Be Your Life: Scenes from the A...  £57.25
# 16                                               Olio  £23.88
# 17  Mesaerion: The Best Science Fiction Stories 18...  £37.59
# 18                       Libertarianism for Beginners  £51.33
# 19                            It's Only the Himalayas  £45.17
#                                                  Book   Price
# 0                                         In Her Wake  £12.84
# 1                                     How Music Works  £37.32
# 2   Foolproof Preserving: A Guide to Small Batch J...  £30.52
# 3                          Chase Me (Paris Nights #2)  £25.27
# 4                                          Black Dust  £34.53
# 5                       Birdsong: A Story in Pictures  £54.64
# 6   America's Cradle of Quarterbacks: Western Penn...  £22.50
# 7                      Aladdin and His Wonderful Lamp  £53.13
# 8   Worlds Elsewhere: Journeys Around Shakespeare’...  £40.30
# 9                                      Wall and Piece  £44.18
# 10  The Four Agreements: A Practical Guide to Pers...  £17.66
# 11  The Five Love Languages: How to Express Heartf...  £31.05
# 12                                  The Elephant Tree  £23.82
# 13                             The Bear and the Piano  £36.89
# 14                                     Sophie's World  £15.94
# 15                                        Penny Maybe  £33.29
# 16     Maude (1883-1993):She Grew Up with the country  £18.02
# 17                               In a Dark, Dark Wood  £19.63
# 18                                Behind Closed Doors  £52.22
# 19                     You can't bury them all: Poems  £33.63
#                                                  Book   Price
# 12  The Long Shadow of Small Ghosts: Murder and Me...  £10.97
# 13                                    The Kite Runner  £41.82
# 14                              The House by the Lake  £36.95
# 15     The Glittering Court (The Glittering Court #1)  £44.28
# 16                              The Girl on the Train  £55.02
# 17                                The Genius of Birds  £17.24
# 18                                The Emerald Mystery  £23.15
# 19  The Cookies & Cups Cookbook: 125+ sweet & savo...  £41.25
#                                                  Book   Price
# 0   The Bridge to Consciousness: I'm Writing the B...  £32.00
# 1   The Artist's Way: A Spiritual Path to Higher C...  £38.49
# 2                                      The Art of War  £33.34
# 3                                       The Argonauts  £10.93
# 4   The 10% Entrepreneur: Live Your Startup Dream ...  £27.55
# 5                    Suddenly in Love (Lake Haven #1)  £55.99
# 6                            Something More Than This  £16.24
# 7                                     Soft Apocalypse  £26.12
# 8                      So You've Been Publicly Shamed  £12.23
# 9           Shoe Dog: A Memoir by the Creator of NIKE  £23.99
# 10                 Shobu Samurai, Project Aryoku (#3)  £29.06
# 11                 Secrets and Lace (Fatal Hearts #1)  £20.27
# 12                     Scarlett Epstein Hates It Here  £43.55
# 13  Romero and Juliet: A Tragic Tale of Love and Z...  £36.94
# 14                                     Redeeming Love  £20.47
# 15  Poses for Artists Volume 1 - Dynamic and Sitti...  £41.06
# 16                    Poems That Make Grown Women Cry  £14.19
# 17                                  Nightingale, Sing  £38.28
# 18                         Night Sky with Exit Wounds  £41.05
# 19                                       Mrs. Houdini  £30.25
#                                                  Book   Price
# 0                                      Modern Romance  £28.26
# 1   Miss Peregrine’s Home for Peculiar Children (M...  £10.76
# 2        Louisa: The Extraordinary Life of Mrs. Adams  £16.85
# 3                                          Little Red  £13.47
# 4   Library of Souls (Miss Peregrine’s Peculiar Ch...  £48.56
# 5                      Large Print Heart of the Pride  £19.15
# 6   I Had a Nice Time And Other Lies...: How to fi...  £57.36
# 7   Hollow City (Miss Peregrine’s Peculiar Childre...  £42.98
# 8                                            Grumbles  £22.16
# 9   Full Moon over Noah’s Ark: An Odyssey to Mount...  £49.43
# 10                     Frostbite (Vampire Academy #2)  £29.99
# 11                                    Follow You Home  £21.36
# 12     First Steps for New Christians (Print Edition)  £29.00
# 13           Finders Keepers (Bill Hodges Trilogy #2)  £53.53
# 14       Fables, Vol. 1: Legends in Exile (Fables #1)  £41.62
# 15                                  Eureka Trivia 6.0  £54.59
# 16  Drive: The Surprising Truth About What Motivat...  £34.95
# 17            Done Rubbed Out (Reightman & Bailey #1)  £37.72
# 18                  Doing It Over (Most Likely To #1)  £35.61
# 19  Deliciously Ella Every Day: Quick and Easy Rec...  £42.16

# %% [markdown]
# # Bonus Challenge 1 - Making Your Spider Unblockable
#
# Use techniques such as randomizing user agents and referers in your requests to reduce the likelihood that your spider is blocked by websites. [Here](http://blog.adnansiddiqi.me/5-strategies-to-write-unblock-able-web-scrapers-in-python/) is a great article to learn these techniques.
#
# In the cell below, place your entire code including the updated `IronhackSpdier` class and the code to kickstart the spider.

# %%
# your code here

# %% [markdown]
# # Bonus Challenge 2 - Making Asynchronous Calls
#
# Implement asynchronous calls to `IronhackSpider`. You will make requests in parallel to complete your tasks faster.
#
# In the cell below, place your entire code including the updated `IronhackSpdier` class and the code to kickstart the spider.

# %%
# your code here
